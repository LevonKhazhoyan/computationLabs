# %%
import numpy as np
from scipy import linalg
from scipy.sparse import diags
import pandas as pd

import sle
from utils import print_matrix


def answer(a: np.ndarray, b: np.ndarray, eps: float = 10e-6) -> None:
    print("Исходная матрица:", end="")
    print_matrix(a)

    print("Правая часть:", end="")
    print_matrix(b)

    print("ε =", eps)
    (x_iter, x_iter_count) = sle.solve(a, b, sle.SolveMethod.SimpleIteration, eps=eps)
    (x_seidel, x_seidel_count) = sle.solve(a, b, sle.SolveMethod.Seidel, eps=eps)

    print("Решение методом простой итерации", end="")
    print_matrix(x_iter)
    print("Количество итераций:", x_iter_count)

    print("Решение методом Зейделя", end="")
    print_matrix(x_seidel)
    print("Количество итераций:", x_seidel_count)

    diff = linalg.norm(x_iter - x_seidel)
    print("||x_iter - x_seidel|| =", diff)

# %%
a1 = np.array([[2, -1, 0], [-1, 2, -1], [0, -1, 2]])
b1 = np.array([[0.5], [1], [1.5]])
answer(a1, b1)
# Out:
# Исходная матрица:
#  2 -1  0
# -1  2 -1
#  0 -1  2
# Правая часть:
# 0.5
# 1.0
# 1.5
# ε = 1e-05
# Решение методом простой итерации
# 1.25
# 2.00
# 1.75
# Количество итераций: 108
# Решение методом Зейделя
# 1.249999
# 1.999999
# 1.749999
# Количество итераций: 20
# ||x_iter - x_seidel|| = 1.3228757794430863
# /Users/levonkhazho/PycharmProjects/compute/sle.py:97: RuntimeWarning: divide by zero encountered in scalar divide
#   diff = norm_big_b / (1 - norm_big_b) * linalg.norm(x - prev_x)
# /Users/levonkhazho/PycharmProjects/compute/sle.py:97: RuntimeWarning: invalid value encountered in scalar multiply
#   diff = norm_big_b / (1 - norm_big_b) * linalg.norm(x - prev_x)

# %%
a2 = np.array([[25, 15, -5], [15, 18, 0], [-5, 0, 11]])
b2 = np.array([[1], [1], [1]])
answer(a2, b2)
# Out:
# Исходная матрица:
# 25 15 -5
# 15 18  0
# -5  0 11
# Правая часть:
# 1
# 1
# 1
# ε = 1e-05
# Решение методом простой итерации
# 0.060740
# 0.004939
# 0.118518
# Количество итераций: 41
# Решение методом Зейделя
# 0.060740
# 0.004939
# 0.118518
# Количество итераций: 19
# ||x_iter - x_seidel|| = 0.19673501930743745

# %%
n = 5
k = [1.5 * np.ones(n - 1), 5 * np.ones(n), -2.7 * np.ones(n - 1)]
offset = [-1, 0, 1]
a3 = diags(k, offset).toarray()
b3 = np.array([[1], [2], [3], [4], [5]])

pd.options.display.float_format = "{:,.16f}".format
answer(a3, b3, eps=10e-12)
# Out:
# Исходная матрица:
# 5.0000000000000000 -2.7000000000000002  0.0000000000000000  0.0000000000000000  0.0000000000000000
# 1.5000000000000000  5.0000000000000000 -2.7000000000000002  0.0000000000000000  0.0000000000000000
# 0.0000000000000000  1.5000000000000000  5.0000000000000000 -2.7000000000000002  0.0000000000000000
# 0.0000000000000000  0.0000000000000000  1.5000000000000000  5.0000000000000000 -2.7000000000000002
# 0.0000000000000000  0.0000000000000000  0.0000000000000000  1.5000000000000000  5.0000000000000000
# Правая часть:
# 1
# 2
# 3
# 4
# 5
# ε = 1e-11
# Решение методом простой итерации
# 0.5807143667916408
# 0.7050266051710281
# 0.8874831763129790
# 0.9240576997472105
# 0.7227826900756164
# Количество итераций: 74
# Решение методом Зейделя
# 0.5807143667920648
# 0.7050266051711349
# 0.8874831763121213
# 0.9240576997473253
# 0.7227826900758025
# Количество итераций: 39
# ||x_iter - x_seidel|| = 0.8923951620394616

# %%
a4 = np.array([[15, 6, 7], [2, -4, -2], [3, 2, 6]])
b4 = np.array([[1.5], [1.5], [1.5]])
answer(a4, b4, eps=10e-15)
# Out:
# Исходная матрица:
# 15  6  7
#  2 -4 -2
#  3  2  6
# Правая часть:
# 1.5000000000000000
# 1.5000000000000000
# 1.5000000000000000
# ε = 1e-14
# Решение методом простой итерации
#  0.1317567567567570
# -0.4814189189189189
#  0.3445945945945947
# Количество итераций: 45
# Решение методом Зейделя
#  0.1317567567567567
# -0.4814189189189191
#  0.3445945945945946
# Количество итераций: 30
# ||x_iter - x_seidel|| = 1.4856531755175884

# %%
# Requires bcsstk05 from SuiteSparse Matrix Collection
from scipy import io

a5 = io.mmread("myMatrix.mtx").toarray()
b5 = np.ones((a5.shape[0], 1))

x5 = linalg.solve(a5, b5)
print(x5)
(x_seidel, x_seidel_count) = sle.solve(a5, b5, sle.SolveMethod.Seidel, eps=10e-15)
# Out:
# [[ 3.18153257e-06]
#  [ 9.32053861e-07]
#  [ 7.11246725e-06]
#  [ 2.14912780e-06]
#  [ 2.67039387e-05]
#  [ 2.00561415e-05]
#  [ 2.86034896e-07]
#  [ 1.64418844e-07]
#  [ 2.88809943e-06]
#  [ 1.11244892e-06]
#  [ 5.45246820e-07]
#  [ 1.65045863e-06]
#  [ 3.02973587e-06]
#  [ 2.85295827e-05]
#  [ 2.26118469e-05]
#  [ 5.13661446e-07]
#  [ 1.36906512e-06]
#  [ 4.36496231e-06]
#  [ 3.10800353e-06]
#  [ 9.71800804e-07]
#  [ 4.84115243e-06]
#  [ 3.69250789e-06]
#  [ 2.90739998e-07]
#  [ 6.30753342e-06]
#  [ 3.61263537e-06]
#  [ 4.63883290e-07]
#  [ 5.49011219e-06]
#  [ 5.05803378e-06]
#  [ 1.14633716e-06]
#  [ 5.51007988e-06]
#  [ 3.14897062e-06]
#  [ 9.55393613e-07]
#  [ 5.49457958e-06]
#  [ 2.62876064e-06]
#  [ 4.65186696e-05]
#  [ 3.26477318e-05]
#  [ 3.01335059e-07]
#  [ 1.75663864e-07]
#  [ 2.63901145e-06]
#  [ 1.49748495e-06]
#  [ 5.57019657e-07]
#  [ 1.96647049e-06]
#  [ 3.76177378e-06]
#  [ 4.95389175e-05]
#  [ 3.53133993e-05]
#  [ 5.02058069e-07]
#  [ 1.21231213e-06]
#  [ 4.02694652e-06]
#  [ 3.53472771e-06]
#  [ 7.76691442e-07]
#  [ 4.49936004e-06]
#  [ 2.81452762e-06]
#  [ 1.77207438e-07]
#  [ 4.71757272e-06]
#  [ 2.57889662e-06]
#  [ 3.97374648e-07]
#  [ 4.02186994e-06]
#  [ 4.20820899e-06]
#  [ 1.14550001e-06]
#  [ 4.16079864e-06]
#  [ 2.13216221e-06]
#  [ 8.59346574e-07]
#  [ 4.00356241e-06]
#  [ 2.07028173e-06]
#  [ 2.70007807e-05]
#  [ 1.67505206e-05]
#  [ 6.09400613e-07]
#  [ 1.46990870e-07]
#  [ 2.67550532e-06]
#  [ 1.60155628e-06]
#  [ 3.36633104e-07]
#  [ 2.01492111e-06]
#  [ 3.31387456e-06]
#  [ 2.78588494e-05]
#  [ 1.92403423e-05]
#  [ 8.39927457e-07]
#  [ 1.04729039e-06]
#  [ 3.62250610e-06]
#  [ 3.27231645e-06]
#  [ 9.57045049e-07]
#  [ 4.05822672e-06]
#  [ 4.80479840e-06]
#  [ 5.92393229e-07]
#  [ 5.51229278e-06]
#  [ 4.03403627e-06]
#  [-1.35401090e-07]
#  [ 5.12563485e-06]
#  [ 7.08054467e-06]
#  [ 4.16075362e-07]
#  [ 4.28583198e-06]
#  [ 2.59588292e-06]
#  [ 1.21200249e-06]
#  [ 4.35273840e-06]
#  [ 6.25062181e-06]
#  [ 5.32298313e-07]
#  [ 5.52843093e-06]
#  [ 5.38576692e-06]
#  [-4.05935369e-07]
#  [ 5.36142092e-06]
#  [ 6.83592652e-06]
#  [ 5.85740571e-07]
#  [ 5.28980965e-06]
#  [ 5.14784091e-06]
#  [ 1.56186126e-06]
#  [ 5.29602210e-06]
#  [ 7.69680168e-06]
#  [ 5.19649509e-07]
#  [ 6.44990491e-06]
#  [ 6.36801081e-06]
#  [-5.81020798e-07]
#  [ 6.30875828e-06]
#  [ 8.83771858e-06]
#  [ 6.72120957e-07]
#  [ 5.84648269e-06]
#  [ 5.38592920e-06]
#  [ 1.79444103e-06]
#  [ 5.77906392e-06]
#  [ 8.11224932e-06]
#  [ 4.66618338e-07]
#  [ 6.60468029e-06]
#  [ 6.74470489e-06]
#  [-5.99085840e-07]
#  [ 6.43794512e-06]
#  [ 8.88319551e-06]
#  [ 8.50879400e-07]
#  [ 6.15580341e-06]
#  [ 6.03045388e-06]
#  [ 1.91839902e-06]
#  [ 9.01325573e-06]
#  [ 5.64150462e-06]
#  [ 1.99415457e-07]
#  [ 3.99552103e-06]
#  [ 7.39077591e-06]
#  [-7.20502049e-07]
#  [ 5.09357160e-06]
#  [ 7.14243303e-06]
#  [ 1.66936366e-06]
#  [ 6.61341502e-06]
#  [ 7.50410115e-06]
#  [ 2.85197187e-06]
#  [ 6.27407054e-06]
#  [ 5.86189183e-06]
#  [ 5.08050207e-07]
#  [ 5.22659199e-06]
#  [ 8.46990254e-06]
#  [-4.82138535e-07]
#  [ 5.16581622e-06]
#  [ 6.84253259e-06]
#  [ 1.74715075e-06]
#  [ 7.63806179e-06]
#  [ 8.31084709e-06]
#  [ 2.88703384e-06]
#  [ 7.45658062e-06]]

# %%
print(x5 - x_seidel)
# Out:
# [[ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [-1.01643954e-20]
#  [ 1.69406589e-21]
#  [ 0.00000000e+00]
#  [-4.23516474e-22]
#  [ 6.35274710e-22]
#  [-1.05879118e-22]
#  [ 0.00000000e+00]
#  [ 4.23516474e-22]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 6.35274710e-22]
#  [-2.11758237e-22]
#  [ 0.00000000e+00]
#  [ 4.23516474e-22]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 8.47032947e-22]
#  [ 5.29395592e-23]
#  [ 0.00000000e+00]
#  [ 4.23516474e-22]
#  [-5.29395592e-23]
#  [ 8.47032947e-22]
#  [ 8.47032947e-22]
#  [ 0.00000000e+00]
#  [-8.47032947e-22]
#  [ 8.47032947e-22]
#  [-2.11758237e-22]
#  [-8.47032947e-22]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 6.77626358e-21]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 2.11758237e-22]
#  [ 1.05879118e-22]
#  [ 0.00000000e+00]
#  [ 4.23516474e-22]
#  [ 0.00000000e+00]
#  [ 1.35525272e-20]
#  [ 0.00000000e+00]
#  [ 2.11758237e-22]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 1.05879118e-22]
#  [ 0.00000000e+00]
#  [-4.23516474e-22]
#  [ 7.94093388e-23]
#  [-8.47032947e-22]
#  [ 4.23516474e-22]
#  [-5.29395592e-23]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 2.11758237e-22]
#  [-8.47032947e-22]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [-8.47032947e-22]
#  [ 0.00000000e+00]
#  [ 3.38813179e-21]
#  [ 0.00000000e+00]
#  [ 8.47032947e-22]
#  [ 2.64697796e-23]
#  [-8.47032947e-22]
#  [ 0.00000000e+00]
#  [-5.29395592e-23]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 3.38813179e-21]
#  [-3.38813179e-21]
#  [ 3.17637355e-22]
#  [ 0.00000000e+00]
#  [-4.23516474e-22]
#  [-8.47032947e-22]
#  [ 2.11758237e-22]
#  [-1.69406589e-21]
#  [ 0.00000000e+00]
#  [ 1.05879118e-22]
#  [-8.47032947e-22]
#  [ 8.47032947e-22]
#  [ 7.94093388e-23]
#  [-1.69406589e-21]
#  [ 0.00000000e+00]
#  [ 1.05879118e-22]
#  [-1.69406589e-21]
#  [ 8.47032947e-22]
#  [ 0.00000000e+00]
#  [-8.47032947e-22]
#  [-8.47032947e-22]
#  [-1.05879118e-22]
#  [-8.47032947e-22]
#  [ 0.00000000e+00]
#  [ 1.05879118e-22]
#  [ 0.00000000e+00]
#  [ 1.69406589e-21]
#  [-4.23516474e-22]
#  [ 0.00000000e+00]
#  [ 2.54109884e-21]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [-1.05879118e-22]
#  [ 8.47032947e-22]
#  [ 1.69406589e-21]
#  [ 1.05879118e-22]
#  [ 0.00000000e+00]
#  [ 3.38813179e-21]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 8.47032947e-22]
#  [ 2.11758237e-22]
#  [-8.47032947e-22]
#  [-1.69406589e-21]
#  [-1.58818678e-22]
#  [-8.47032947e-22]
#  [ 2.54109884e-21]
#  [ 0.00000000e+00]
#  [-8.47032947e-22]
#  [-1.69406589e-21]
#  [ 3.17637355e-22]
#  [ 0.00000000e+00]
#  [ 2.54109884e-21]
#  [-4.23516474e-22]
#  [ 0.00000000e+00]
#  [ 1.69406589e-21]
#  [ 2.11758237e-22]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 2.11758237e-22]
#  [-8.47032947e-22]
#  [ 0.00000000e+00]
#  [-2.11758237e-22]
#  [ 8.47032947e-22]
#  [ 8.47032947e-22]
#  [-4.23516474e-22]
#  [ 1.69406589e-21]
#  [ 1.69406589e-21]
#  [ 3.17637355e-22]
#  [ 8.47032947e-22]
#  [ 5.08219768e-21]
#  [-3.17637355e-22]
#  [ 8.47032947e-22]
#  [ 8.47032947e-22]
#  [-6.35274710e-22]
#  [ 1.69406589e-21]
#  [ 0.00000000e+00]
#  [-8.47032947e-22]
#  [ 3.38813179e-21]]
